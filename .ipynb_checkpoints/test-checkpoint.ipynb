# %%
# !conda list
# Out:
# # packages in environment at /home/nbuser/anaconda2_501:
# #
# _ipyw_jlab_nb_ext_conf    0.1.0            py27h08a7f0c_0
# adal                      0.5.1                     <pip>
# alabaster                 0.7.10           py27he5a193a_0
# altair                    1.2.1                     <pip>
# anaconda                  custom                   py27_0
# anaconda-client           1.6.5            py27hc8169bf_0
# anaconda-navigator        1.6.9            py27hfbc306d_0
# anaconda-project          0.8.0            py27hd7a9a97_0
# applicationinsights       0.11.2                    <pip>
# argcomplete               1.9.4                     <pip>
# arrow                     0.12.1                    <pip>
# asn1crypto                0.22.0           py27h94ebe91_1
# astroid                   1.5.3            py27h8f8f47c_0
# astropy                   2.0.2            py27h57072c0_4
# attrs                     17.4.0                    <pip>
# ...
